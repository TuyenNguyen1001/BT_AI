# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder= '/content/drive/MyDrive/AI/Food/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder+'BanhBao'+str(i+1)+'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder = '/content/drive/MyDrive/AI/Food/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('BanhBao'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhCam'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Banhmy'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhTet'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('BanhTrungThu'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('ComTam'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Pho'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('Salad'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('SuonXaoChuaNgot'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('TomRim'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# (90, 200, 200, 3) (90,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten # BatchNormalization: để dùng GPU ko lỗi

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', 
                 input_shape=(200, 200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))


model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
 history = model.fit(photos, labels, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 106ms/step - loss: 4.3880e-06 - accuracy: 1.0000
# Epoch 2/100
# 3/3 [==============================] - 0s 95ms/step - loss: 4.2661e-06 - accuracy: 1.0000
# Epoch 3/100
# 3/3 [==============================] - 0s 88ms/step - loss: 4.1853e-06 - accuracy: 1.0000
# Epoch 4/100
# 3/3 [==============================] - 0s 88ms/step - loss: 4.0900e-06 - accuracy: 1.0000
# Epoch 5/100
# 3/3 [==============================] - 0s 87ms/step - loss: 3.9827e-06 - accuracy: 1.0000
# Epoch 6/100
# 3/3 [==============================] - 0s 90ms/step - loss: 3.9218e-06 - accuracy: 1.0000
# Epoch 7/100
# 3/3 [==============================] - 0s 84ms/step - loss: 3.8171e-06 - accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 98ms/step - loss: 3.7377e-06 - accuracy: 1.0000
# Epoch 9/100
# 3/3 [==============================] - 0s 107ms/step - loss: 3.6556e-06 - accuracy: 1.0000
# Epoch 10/100
# ...

# %%
model.evaluate(photos,labels)
# Out:
# 3/3 [==============================] - 0s 47ms/step - loss: 4.5299e-07 - accuracy: 1.0000
# [4.529890702542616e-07, 1.0]

# %%
model.save('Foods_Train.h5')

# %%
from keras.models import load_model
models=load_model('10Foods_Final.h5')

# %%
classes = ["BanhBao","BanhCam","Banhmy","BanhTet","BanhTrungThu","ComTam","Pho","Salad","SuonXaoChuaNgot","TomRim"]

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('../content/drive/MyDrive/AI/Food/TomRim1.jpg', target_size=(200,200))
plt.imshow(img)

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.08715042 0.10095076 0.08808745 0.08978983 0.10206354 0.10587926
#   0.09843057 0.11402985 0.08700932 0.12660898]]
# 'TomRim'
